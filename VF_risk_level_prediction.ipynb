# %%
import pandas as pd
import numpy as np

# %%
Dataset=pd.read_csv('/content/Raw_Females_VF_Dataset.csv')

# %%
Dataset.head(100)
# Out:
#    SUBJECT_ID SEX  AGE_years  BMI   HEIGHT_cm  WEIGHT_kg  \
# 0       A0011   F         53    30      170.8      79.66
# 1       A0012   F         64    23      169.0      58.28
# 2       A0013   F         46    21      173.0      57.16
# 3       A0014   F         45    26      158.0      56.84
# 4       A0015   F         61    40      168.0     104.08
# ..        ...  ..        ...   ...        ...        ...
# 95      A0106   F         66    22      160.0      52.41
# 96      A0107   F         43    21      183.0      66.63
# 97      A0108   F         58    27      172.0      73.10
# 98      A0109   F         47    37      162.0      93.88
# 99      A0110   F         62    33      163.0      79.41
#
#     WAIST_CIRCUMFERENCE_cm  DIASTOLIC_BLOOD_PRESSURE_mmHg  \
# 0                       92                            105
# 1                       67                             77
# 2                       73                             81
# ...

# %%
Dataset.isna().sum()
# Out:
# SUBJECT_ID                            0
# SEX                                   0
# AGE_years                             0
# BMI                                   0
# HEIGHT_cm                             0
# WEIGHT_kg                             0
# WAIST_CIRCUMFERENCE_cm                0
# DIASTOLIC_BLOOD_PRESSURE_mmHg         0
# SYSTOLIC_BLOOD_PRESSURE_mmHg         11
# WALK_DURATION_PER_DAY_MINUTES         0
# COMPUTER_USE_TIME_PER_DAY_HOURS       0
# SMOKING_STATUS                        2
# DISCONTINUED_NO_                   3154
# CIGARETTES_CONSUMED_PER_DAY        2993
# Visceral_Fat_Volume_Litres            0
# dtype: int64

# %%
percentage_missing_values=Dataset.isna().sum()/len(Dataset)*100

# %%
percentage_missing_values
# Out:
# SUBJECT_ID                          0.000000
# SEX                                 0.000000
# AGE_years                           0.000000
# BMI                                 0.000000
# HEIGHT_cm                           0.000000
# WEIGHT_kg                           0.000000
# WAIST_CIRCUMFERENCE_cm              0.000000
# DIASTOLIC_BLOOD_PRESSURE_mmHg       0.000000
# SYSTOLIC_BLOOD_PRESSURE_mmHg        0.348542
# WALK_DURATION_PER_DAY_MINUTES       0.000000
# COMPUTER_USE_TIME_PER_DAY_HOURS     0.000000
# SMOKING_STATUS                      0.063371
# DISCONTINUED_NO_                   99.936629
# CIGARETTES_CONSUMED_PER_DAY        94.835234
# Visceral_Fat_Volume_Litres          0.000000
# dtype: float64

# %%
correlation_matrix = Dataset.corr()
correlation_matrix
# Out:
#                                  AGE_years      BMI   HEIGHT_cm  WEIGHT_kg  \
# AGE_years                         1.000000  0.002514  -0.136592  -0.083577
# BMI                               0.002514  1.000000  -0.196795   0.862212
# HEIGHT_cm                        -0.136592 -0.196795   1.000000   0.221060
# WEIGHT_kg                        -0.083577  0.862212   0.221060   1.000000
# WAIST_CIRCUMFERENCE_cm            0.048917  0.797807   0.040237   0.827749
# DIASTOLIC_BLOOD_PRESSURE_mmHg     0.012629  0.242239  -0.018452   0.238778
# SYSTOLIC_BLOOD_PRESSURE_mmHg      0.279479  0.167929  -0.090782   0.131954
# WALK_DURATION_PER_DAY_MINUTES    -0.020069 -0.064364   0.003161  -0.074226
# COMPUTER_USE_TIME_PER_DAY_HOURS  -0.072413  0.147637  -0.003626   0.148791
# SMOKING_STATUS                   -0.021911 -0.008654  -0.043824  -0.019042
# CIGARETTES_CONSUMED_PER_DAY       0.006083  0.006560  -0.086250   0.008908
# ...

# %%
Dataset.drop(['SUBJECT_ID','SEX','DISCONTINUED_NO_'],axis=1,inplace=True)

# %%
Dataset.head(10)
# Out:
#    AGE_years  BMI   HEIGHT_cm  WEIGHT_kg  WAIST_CIRCUMFERENCE_cm  \
# 0         53    30      170.8      79.66                      92
# 1         64    23      169.0      58.28                      67
# 2         46    21      173.0      57.16                      73
# 3         45    26      158.0      56.84                      73
# 4         61    40      168.0     104.08                      96
# 5         66    36      173.0     100.40                      92
# 6         63    31      163.0      75.34                      95
# 7         45    21      166.0      54.26                      77
# 8         49    25      167.0      61.30                      75
# 9         45    25      161.6      58.91                      69
#
#    DIASTOLIC_BLOOD_PRESSURE_mmHg  SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# 0                            105                         143.0
# 1                             77                          95.0
# ...

# %%
Dataset.isna().sum()
# Out:
# AGE_years                             0
# BMI                                   0
# HEIGHT_cm                             0
# WEIGHT_kg                             0
# WAIST_CIRCUMFERENCE_cm                0
# DIASTOLIC_BLOOD_PRESSURE_mmHg         0
# SYSTOLIC_BLOOD_PRESSURE_mmHg         11
# WALK_DURATION_PER_DAY_MINUTES         0
# COMPUTER_USE_TIME_PER_DAY_HOURS       0
# SMOKING_STATUS                        2
# CIGARETTES_CONSUMED_PER_DAY        2993
# Visceral_Fat_Volume_Litres            0
# dtype: int64

# %%
Dataset.describe()
# Out:
#          AGE_years         BMI     HEIGHT_cm    WEIGHT_kg  \
# count  3156.000000  3156.000000  3156.000000  3156.000000
# mean     60.891001    28.510456   169.652725    76.256980
# std       8.379783     4.582564     8.231651    13.042267
# min      41.000000    18.000000     1.500000    48.290000
# 25%      55.000000    25.000000   165.000000    67.320000
# 50%      61.000000    28.000000   170.000000    74.090000
# 75%      67.000000    31.000000   174.000000    83.000000
# max     180.000000    63.000000   206.000000   163.350000
#
#        WAIST_CIRCUMFERENCE_cm  DIASTOLIC_BLOOD_PRESSURE_mmHg  \
# count             3156.000000                    3156.000000
# mean                87.613118                      88.385615
# std                 11.564449                      10.735779
# min                 58.000000                      54.000000
# 25%                 79.000000                      81.000000
# 50%                 86.000000                      88.000000
# ...

# %%
Dataset.dtypes
# Out:
# AGE_years                            int64
# BMI                                  int64
# HEIGHT_cm                          float64
# WEIGHT_kg                          float64
# WAIST_CIRCUMFERENCE_cm               int64
# DIASTOLIC_BLOOD_PRESSURE_mmHg        int64
# SYSTOLIC_BLOOD_PRESSURE_mmHg       float64
# WALK_DURATION_PER_DAY_MINUTES        int64
# COMPUTER_USE_TIME_PER_DAY_HOURS      int64
# SMOKING_STATUS                     float64
# CIGARETTES_CONSUMED_PER_DAY        float64
# Visceral_Fat_Volume_Litres         float64
# dtype: object

# %%
import numpy as np

# %%
Dataset.columns
# Out:
# Index(['AGE_years', 'BMI ', 'HEIGHT_cm', 'WEIGHT_kg', 'WAIST_CIRCUMFERENCE_cm',
#        'DIASTOLIC_BLOOD_PRESSURE_mmHg', 'SYSTOLIC_BLOOD_PRESSURE_mmHg',
#        'WALK_DURATION_PER_DAY_MINUTES', 'COMPUTER_USE_TIME_PER_DAY_HOURS',
#        'SMOKING_STATUS ', 'CIGARETTES_CONSUMED_PER_DAY',
#        'Visceral_Fat_Volume_Litres'],
#       dtype='object')

# %%
Dataset['SMOKING_STATUS'] = np.where(Dataset['CIGARETTES_CONSUMED_PER_DAY'] > 0, 1,0)

# %%
Dataset['CIGARETTES_CONSUMED_PER_DAY']=Dataset['CIGARETTES_CONSUMED_PER_DAY'].fillna(0)

# %%
Dataset['CIGARETTES_CONSUMED_PER_DAY']=np.array(Dataset['CIGARETTES_CONSUMED_PER_DAY'], np.int16)

# %%
Dataset['SYSTOLIC_BLOOD_PRESSURE_mmHg'] = Dataset['SYSTOLIC_BLOOD_PRESSURE_mmHg'].fillna(Dataset.mean)

# %%
Dataset =Dataset.drop(Dataset[Dataset.AGE_years > 110].index)

# %%
Dataset =Dataset.drop(Dataset[Dataset.HEIGHT_cm < 2].index)

# %%
Dataset =Dataset.drop(Dataset[Dataset.COMPUTER_USE_TIME_PER_DAY_HOURS > 22].index)

# %%
Dataset.head()
# Out:
#    AGE_years  BMI   HEIGHT_cm  WEIGHT_kg  WAIST_CIRCUMFERENCE_cm  \
# 0         53    30      170.8      79.66                      92
# 1         64    23      169.0      58.28                      67
# 2         46    21      173.0      57.16                      73
# 3         45    26      158.0      56.84                      73
# 4         61    40      168.0     104.08                      96
#
#    DIASTOLIC_BLOOD_PRESSURE_mmHg SYSTOLIC_BLOOD_PRESSURE_mmHg  \
# 0                            105                        143.0
# 1                             77                         95.0
# 2                             81                        103.0
# 3                             74                        100.0
# 4                             89                        115.0
#
#    WALK_DURATION_PER_DAY_MINUTES  COMPUTER_USE_TIME_PER_DAY_HOURS  \
# 0                             78                                3
# ...

# %%
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3075b36c09c8> in <cell line: 1>()
# ----> 1 dataset
#
# NameError: name 'dataset' is not defined

# %%
Dataset['Risk_Level']  = np.where(Dataset["Visceral_Fat_Volume_Litres"] >= 2, "Yes", "No")

# %%
Dataset['Risk_Level']
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 3150    Yes
# 3151    Yes
# 3152    Yes
# 3153    Yes
# 3154    Yes
# Name: Risk_Level, Length: 3140, dtype: object

# %%
array=np.array(Dataset['Risk_Level'])

# %%
unique_values, counts = np.unique(array[:], return_counts=True)

# %%
unique_values, counts
# Out:
# (array(['No', 'Yes'], dtype=object), array([ 549, 2591]))

# %%
Dataset.drop(['Visceral_Fat_Volume_Litres'],axis=1,inplace=True)

# %%
correlation_matrix = Dataset.corr()
correlation_matrix
# Out:
#                                  AGE_years      BMI   HEIGHT_cm  WEIGHT_kg  \
# AGE_years                         1.000000 -0.009180  -0.171517  -0.098149
# BMI                              -0.009180  1.000000  -0.235504   0.860832
# HEIGHT_cm                        -0.171517 -0.235504   1.000000   0.249836
# WEIGHT_kg                        -0.098149  0.860832   0.249836   1.000000
# WAIST_CIRCUMFERENCE_cm            0.032975  0.796760   0.030047   0.827200
# DIASTOLIC_BLOOD_PRESSURE_mmHg     0.009968  0.239232  -0.022779   0.235928
# WALK_DURATION_PER_DAY_MINUTES    -0.016800 -0.061834  -0.001085  -0.072140
# COMPUTER_USE_TIME_PER_DAY_HOURS  -0.057132  0.140646  -0.000630   0.146870
# SMOKING_STATUS                   -0.020582 -0.007978  -0.018275  -0.017113
# CIGARETTES_CONSUMED_PER_DAY      -0.018975 -0.013169  -0.009662  -0.019294
# SMOKING_STATUS                   -0.023134 -0.016013  -0.016114  -0.024203
#
#                                  WAIST_CIRCUMFERENCE_cm  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
#split dataset in features and target variable
feature_cols = ['AGE_years', 'BMI ', 'HEIGHT_cm', 'WEIGHT_kg', 'WAIST_CIRCUMFERENCE_cm',
       'DIASTOLIC_BLOOD_PRESSURE_mmHg', 'SYSTOLIC_BLOOD_PRESSURE_mmHg',
       'WALK_DURATION_PER_DAY_MINUTES', 'COMPUTER_USE_TIME_PER_DAY_HOURS',
       'SMOKING_STATUS ', 'CIGARETTES_CONSUMED_PER_DAY', 'Risk_Level']
X = Dataset[feature_cols] # Features
y = Dataset.Risk_Level # Target variable

# %%
X = X.apply(pd.to_numeric, errors='coerce')
X.fillna(0, inplace=True)

# %%
from imblearn.over_sampling import SMOTE

X_resampled, y_resampled = SMOTE().fit_resample(X, y)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X1 = scaler.fit_transform(X_resampled)

# %%
X1
# Out:
# array([[0.30769231, 0.26666667, 0.40338983, ..., 0.        , 0.        ,
#         0.        ],
#        [0.58974359, 0.11111111, 0.37288136, ..., 0.        , 0.        ,
#         0.        ],
#        [0.12820513, 0.06666667, 0.44067797, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.43589744, 0.2       , 0.30655349, ..., 0.        , 0.        ,
#         0.        ],
#        [0.64102564, 0.17777778, 0.31532227, ..., 0.        , 0.        ,
#         0.        ],
#        [0.48717949, 0.17777778, 0.24575496, ..., 0.        , 0.        ,
#         0.        ]])

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X1_train,X1_test,y_train,y_test=train_test_split(X1,y_resampled,test_size=0.30,random_state=42)

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(criterion="entropy",max_depth=4)

# Train Decision Tree Classifer
clf = clf.fit(X1_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X1_test)

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8014861995753716

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.01      0.50      0.02         4
#          Yes       1.00      0.80      0.89       938
#
#     accuracy                           0.80       942
#    macro avg       0.50      0.65      0.46       942
# weighted avg       0.99      0.80      0.89       942

# %%
from sklearn.neighbors import KNeighborsClassifier
# Create KNN classifier
knn = KNeighborsClassifier(n_neighbors = 8)
# Fit the classifier to the data
knn.fit(X1_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
#show first 5 model predictions on the test data
y_pred=knn.predict(X1_test)

# %%
#check accuracy of our model on the test data
knn.score(X1_test, y_test)
# Out:
# 0.7760084925690022

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.17      0.36      0.23        88
#          Yes       0.93      0.82      0.87       854
#
#     accuracy                           0.78       942
#    macro avg       0.55      0.59      0.55       942
# weighted avg       0.86      0.78      0.81       942

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X1_train, y_train)
# Out:
# GaussianNB()

# %%
print("Naive Bayes score: ",nb.score(X1_test, y_test))
# Out:
# Naive Bayes score:  0.7420382165605095

# %%
y_pred=nb.predict(X1_test)

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.88      0.68      0.77      1041
#          Yes       0.56      0.82      0.66       514
#
#     accuracy                           0.73      1555
#    macro avg       0.72      0.75      0.72      1555
# weighted avg       0.78      0.73      0.73      1555

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=1000, alpha=0.0001, solver='adam', random_state=42)

mlp.fit(X1_train,y_train)

predict_train = mlp.predict(X1_train)
predict_test = mlp.predict(X1_test)

# %%
score = mlp.score(X1_test, y_test)
print(f"Accuracy: {score}")
# Out:
# Accuracy: 0.7639871382636656

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_train,predict_train))
print(classification_report(y_train,predict_train))
# Out:
# [[1490  303]
#  [ 528 1306]]
#               precision    recall  f1-score   support
#
#           No       0.74      0.83      0.78      1793
#          Yes       0.81      0.71      0.76      1834
#
#     accuracy                           0.77      3627
#    macro avg       0.78      0.77      0.77      3627
# weighted avg       0.78      0.77      0.77      3627

# %%
print(confusion_matrix(y_test,predict_test))
print(classification_report(y_test,predict_test))
# Out:
# [[666 132]
#  [235 522]]
#               precision    recall  f1-score   support
#
#           No       0.74      0.83      0.78       798
#          Yes       0.80      0.69      0.74       757
#
#     accuracy                           0.76      1555
#    macro avg       0.77      0.76      0.76      1555
# weighted avg       0.77      0.76      0.76      1555

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
y_true_numeric = le.fit_transform(y_test)
y_pred_numeric = le.transform(predict_test)

# %%
from sklearn.metrics import roc_auc_score
auc_roc_score = roc_auc_score(y_true_numeric, y_pred_numeric)

# %%
auc_roc_score
# Out:
# 0.7620752674288097
